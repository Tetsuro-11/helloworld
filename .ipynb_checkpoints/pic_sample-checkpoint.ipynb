# %% [markdown]
# <a href="https://diveintocode.gyazo.com/29840c67d7aabcd16c3dd5325819ec65"><img src="https://t.gyazo.com/teams/diveintocode/29840c67d7aabcd16c3dd5325819ec65.png" alt="Image from Gyazo" width="358"/></a>

# %%
from IPython.display import Image
Image("https://t.gyazo.com/teams/diveintocode/29840c67d7aabcd16c3dd5325819ec65.png")

# %% [markdown]
# ![データセット](https://t.gyazo.com/teams/diveintocode/29840c67d7aabcd16c3dd5325819ec65.png)
